# %%
kinolar = {
    "Inception": 8.8,
    "Interstellar": 8.6,
    "The Dark Knight": 9.0,
    "Avatar": 7.8,
    "The Matrix": 8.7
}
print("Kinolar bazasi muvaffaqiyatli yuklandi!")
kinolar = {
    "Interstellar": 8.7,
    "The Godfather": 9.2,
    "Inception": 8.8,
    "The Matrix": 8.7,
    "Titanic": 7.9
}

yuqori_reytingli_kinolar = {
    film: reyting
    for film, reyting in kinolar.items()
    if reyting > 8.5
}

print(yuqori_reytingli_kinolar)
# Out:
# Kinolar bazasi muvaffaqiyatli yuklandi!
# {'Interstellar': 8.7, 'The Godfather': 9.2, 'Inception': 8.8, 'The Matrix': 8.7}
